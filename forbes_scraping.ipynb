# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup
from IPython.display import clear_output

# %% [markdown]
# We can get a lot of data straight from the Forbes API <br>
# (see forbes_api.ipynb notebook)

# %%
df=pd.read_csv('data/2020_Billionaires.csv')
df.head()
# Out:
#    Unnamed: 0                  name  lastName             uri      imageUri  \
# 0           0       A. Jayson Adair     Adair  a-jayson-adair        no-pic
# 1           1             Abhay Soi       Soi       abhay-soi        no-pic
# 2           2         Adam Foroughi  Foroughi   adam-foroughi        no-pic
# 3           3          Adam Neumann   Neumann    adam-neumann  adam-neumann
# 4           4  Alan Miller & family    Miller   alan-miller-1        no-pic
#
#    worthChange   age               source               industry gender  ...  \
# 0      -12.191  52.0         damaged cars             Automotive      M  ...
# 1       31.453  48.0           healthcare             Healthcare      M  ...
# 2     -147.507  41.0         mobile games  Media & Entertainment      M  ...
# 3      -19.834  42.0              WeWork             Real Estate      M  ...
# 4       -5.252  84.0  healthcare services             Healthcare      M  ...
#
#   realTimeRank  realTimePosition  \
# 0       2210.0            2210.0
# 1       2576.0            2576.0
# 2       1337.0            1337.0
# 3       2081.0            2081.0
# 4       2338.0            2338.0
#
#                                          squareImage position  rank  worth  \
# 0  https://specials-images.forbesimg.com/imageser...      NaN   NaN    NaN
# 1  https://specials-images.forbesimg.com/imageser...      NaN   NaN    NaN
# 2                                                NaN      NaN   NaN    NaN
# 3  //specials-images.forbesimg.com/imageserve/5e7...      NaN   NaN    NaN
# 4                                                NaN      NaN   NaN    NaN
#
#    title government  pay  managementAssets
# 0    NaN        NaN  NaN               NaN
# 1    NaN        NaN  NaN               NaN
# 2    NaN        NaN  NaN               NaN
# 3    NaN        NaN  NaN               NaN
# 4    NaN        NaN  NaN               NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# but there is more data to be found in the individual profile Forbes writes for each billionaires, including wether they were self-made, current residence, etc...  <br>
# These can be accessed using Forbes ID (uri) for each billionaires   <br>

# %% [markdown]
# # 1. Data Extraction

# %% [markdown]
# Wrapper functions for BeautifullSoup

# %%
#This functions retrieve all the stats displayed on a particular Forbes profile 
def get_stats(soup):
    stats=soup.find_all(class_="listuser-block__item")
    title=[]
    value=[]

    if stats:
        for n_stat in stats:
            title.append(n_stat.find(class_="profile-stats__title").text)
            value.append(n_stat.find(class_="profile-stats__text").text)

    return dict(zip(title, value))

#This function retrieves the text description of each billionaires
def get_text(soup):
    txt=soup.find(class_='profile-text')
    s=""
    if txt and txt.text: #check if txt is empty 
        if txt.ul and txt.ul.children:
            for line in txt.ul.children:
                s+=(line.text)
        else:  #sometimes txt is just one block of text without <ul> elements
            s+=txt.text
    return s

# %% [markdown]
# extracting the profile infos for each billionaires

# %%
#there is aprox. 2800 pages to load from Forbes website
# so this block takes some time to execute

#output lists 
l_index=[]
l_text=[]
l_stats=[]

#iterate on each billionaires in Forbes' 2020 list 
for index, row in df.iterrows():
    l_index.append(index)

    re=requests.get(f'https://www.forbes.com/profile/{row.uri}')
    soup=BeautifulSoup(re.content, "html.parser")

    l_text.append(get_text(soup))
    l_stats.append(get_stats(soup))

    #print progress
    clear_output(wait=True)
    print(f'{index}_{row.uri}')
# Out:
# 2818_zhou-yongli

# %% [markdown]
# Putting the data in one data table

# %%
data=[l_index, l_text, l_stats]
df2=pd.DataFrame(data=data)
df2=df2.transpose()

df2=df2.set_axis(["index", "text", 'stats'], axis=1, inplace=False)
df2=df2.drop(columns="index")

df2.head()
df2.to_csv("data/2020_forbes_profile.csv")
# Out:
#          0                                                  1  \
# 0        0  A. Jayson "Jay" Adair is the CEO of Dallas-bas...
# 1        1  Former finance professional Abhay So is chairm...
# 2        2  Adam Foroughi is the cofounder and CEO of AppL...
# 3        3  Adam Neumann is a cofounder of coworking firm ...
# 4        4  Miller founded Universal Health Services, a ch...
# ...    ...                                                ...
# 2814  2814  Yu Qibing chairs the Kibing Group, an industri...
# 2815  2815  Zhang Yuxiang is the chairman of Nanjids (Shan...
# 2816  2816  Zhao Hongfei chairs Shenzhen-listed software f...
# 2817  2817  Konstyantin Zhevago owns a majority stake in U...
# 2818  2818  Zhou Yongli chairs Yongli Group, a business wi...
#
#                                                       2
# 0     {'Age': '52', 'Source of Wealth': 'damaged car...
# 1     {'Age': '48', 'Source of Wealth': 'healthcare,...
# 2     {'Age': '41', 'Source of Wealth': 'mobile game...
# 3     {'Age': '42', 'Source of Wealth': 'WeWork, Sel...
# 4     {'Age': '84', 'Source of Wealth': 'healthcare ...
# ...                                                 ...
# 2814  {'Age': '56', 'Source of Wealth': 'glass, Self...
# 2815  {'Age': '57', 'Source of Wealth': 'apparel, Se...
# 2816  {'Age': '47', 'Source of Wealth': 'software, S...
# 2817  {'Age': '47', 'Source of Wealth': 'mining, Sel...
# 2818  {'Age': '66', 'Source of Wealth': 'conglomerat...
#
# [2819 rows x 3 columns]

# %% [markdown]
# # 2. Data formating

# %% [markdown]
# Checking if the billionaire is considered "self-made" or not

# %%
def self_made(dic):
    if dic and "Source of Wealth" in dic.keys() :
        if "self made" in dic["Source of Wealth"].lower():
            return True    
    return False


df2["self_made"]=df2.apply(lambda row: self_made(row.stats), axis=1)

# %% [markdown]
# Extracting all the data contained in df2['stats] in a way that handles the many missing values

# %%
stats=df2['stats'].apply(pd.Series)

# %% [markdown]
# We can see some columns have mostly complete data e.g. "Source of Wealth", "Residence", etc. <br>
# and some columns have very little data e.g. "Agent", "Agency", "Notable Deal", etc.

# %%
stats.describe()
# Out:
#          Age        Source of Wealth           Residence    Citizenship  \
# count   2652                    2788                2729           2777
# unique    76                    1056                 772             73
# top       58  real estate, Self Made  New York, New York  United States
# freq      95                     136                 104            757
#
#        Marital Status Children             Education Self-Made Score  \
# count            2120     1616                  1473             585
# unique              8       14                  1176              10
# top           Married        2  Diploma, High School               8
# freq             1759      553                    24             224
#
#        Philanthropy Score       Agent Agency Notable Deal Salary/Winnings  \
# count                 413           2      2            3               1
# unique                  5           1      1            3               1
# top                     1  David Falk   FAME    Snowflake            $1 M
# freq                  183           2      2            1               1
#
#        Lifetime Giving Giving as a percentage of net worth  \
# count                5                                   5
# unique               5                                   4
# top              $1.8B                                  7%
# freq                 1                                   2
#
#                                              Clients
# count                                              1
# unique                                             1
# top     Robinson Cano, Yoenis Cespedes, Kyrie Irving
# freq                                               1

# %% [markdown]
# Cleaning up the data

# %%
#Some variable name formating
stats["source"]=stats["Source of Wealth"]

#Selecting the relevant columns
stats=stats[ ['source', 'Source of Wealth', 'Residence', 'Citizenship', 'Marital Status',
       'Children', 'Education', 'Self-Made Score', 'Philanthropy Score',
       ]]

#Appending the self-made information
stats["self_made"]=df2["self_made"]
stats.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11800/82227960.py in <module>
#       1 #Some variable name formating
# ----> 2 stats["source"]=stats["Source of Wealth"]
#       3
#       4 #Selecting the relevant columns
#       5 stats=stats[ ['source', 'Source of Wealth', 'Residence', 'Citizenship', 'Marital Status',
#
# NameError: name 'stats' is not defined

# %% [markdown]
# # 3. Merging datasets

# %%
#merging the 'stats' data extracted from the individual Forbes profile with the Forbes list 
df_clean=df[[ 'name', 'lastName', 'uri', 'worthChange',
       'age', 'source', 'industry', 'gender', 'country',
       'realTimeWorth'
       ]]
#merging both datasets
df_clean= df_clean.merge(right=stats, how="left", left_index=True, right_index=True)
df_clean.head()

df_clean.to_csv("data/2020_data_clean.csv")
# Out:
#                    name  lastName             uri  worthChange   age  \
# 0       A. Jayson Adair     Adair  a-jayson-adair      -12.191  52.0
# 1             Abhay Soi       Soi       abhay-soi       31.453  48.0
# 2         Adam Foroughi  Foroughi   adam-foroughi     -147.507  41.0
# 3          Adam Neumann   Neumann    adam-neumann      -19.834  42.0
# 4  Alan Miller & family    Miller   alan-miller-1       -5.252  84.0
#
#               source_x               industry gender        country  \
# 0         damaged cars             Automotive      M  United States
# 1           healthcare             Healthcare      M          India
# 2         mobile games  Media & Entertainment      M  United States
# 3              WeWork             Real Estate      M         Israel
# 4  healthcare services             Healthcare      M  United States
#
#    realTimeWorth                           source_y  \
# 0       1376.511         [damaged cars,  Self Made]
# 1       1078.053           [healthcare,  Self Made]
# 2       2536.112         [mobile games,  Self Made]
# 3       1498.747               [WeWork,  Self Made]
# 4       1260.555  [healthcare services,  Self Made]
#
#                  Source of Wealth                   Residence    Citizenship  \
# 0         damaged cars, Self Made               Dallas, Texas  United States
# 1           healthcare, Self Made               Mumbai, India          India
# 2         mobile games, Self Made         Truckee, California  United States
# 3               WeWork, Self Made          New York, New York         Israel
# 4  healthcare services, Self Made  Lower Merion, Pennsylvania  United States
#
#   Marital Status Children                                          Education  \
# 0        Married        2                                                NaN
# 1        Married        2  Master of Business Administration, European Un...
# 2        Married      NaN                                                NaN
# 3        Married        5                 City University of New York Baruch
# 4        Married        3  Bachelor of Arts/Economics, College of William...
#
#   Self-Made Score Philanthropy Score  self_made
# 0             NaN                NaN       True
# 1             NaN                NaN       True
# 2             NaN                NaN       True
# 3             NaN                NaN       True
# 4             NaN                NaN       True
